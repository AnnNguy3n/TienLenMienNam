# %%
import gym
import gym_TLMN
from colorama import Fore, Style


def main():
    env = gym.make('gym_TLMN-v0')
    env.reset()

    # print([i.name for i in env.players])

    for i in range(500):
        env.render()

        o,a,done,t = env.step(env.turn.action(env.dict_input))
        if done:
            break

    print(Fore.LIGHTGREEN_EX, 'Win, name:', Fore.LIGHTMAGENTA_EX, env.p_name_victory, Fore.LIGHTCYAN_EX, '0', end='   ')
    for p in env.players:
        if p.name != env.p_name_victory:
            print(Fore.LIGHTRED_EX, 'Lose, name:', Fore.LIGHTMAGENTA_EX, p.name, Fore.LIGHTCYAN_EX, p.amount_cards_remaining, end='   ')
    
    print(Style.RESET_ALL)

    for i in range(env.players.__len__()):
        env.render()

        o,a,done,t = env.step(env.turn.action(env.dict_input))

    return env.p_name_victory

# %%
main()
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 0. 4_Heart, 1. 7_Club, 2. 7_Diamond, 3. 7_Heart, 4. 8_Spade, 5. 8_Club, 6. 9_Diamond, 7. 10_Spade, 8. Queen_Spade, 9. King_Club, 10. King_Diamond, 11. 2_Spade, 12. 2_Heart,
# [0, 8, 18, 19, 20, 21, 22, 27, 29, 37, 42, 43, 49, 52, 66, 67, 68, 84, 91, 101, 148, 150, 186]
# 8
# Bắc khởi đầu vòng mới với: 4_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. 10_Heart, 9. Queen_Club, 10. King_Spade, 11. King_Heart, 12. Ace_Heart,
# [0, 12, 14, 15, 24, 25, 30, 32, 38, 41, 44, 48]
# 32
# Tây chặt bài với: 10_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Spade, 3. 6_Heart, 4. 8_Diamond, 5. 9_Club, 6. 9_Heart, 7. 10_Diamond, 8. Jack_Spade, 9. Jack_Club, 10. Queen_Diamond, 11. Queen_Heart, 12. Ace_Spade,
# [0, 33, 34, 39, 40, 45]
# 40
# Nam chặt bài với: Queen_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 3_Club, 2. 3_Diamond, 3. 4_Club, 4. 5_Club, 5. 5_Diamond, 6. 7_Spade, 7. Jack_Diamond, 8. Jack_Heart, 9. Ace_Club, 10. Ace_Diamond, 11. 2_Club, 12. 2_Diamond,
# [0, 46, 47, 50, 51]
# 47
# Đông chặt bài với: Ace_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 7_Club, 1. 7_Diamond, 2. 7_Heart, 3. 8_Spade, 4. 8_Club, 5. 9_Diamond, 6. 10_Spade, 7. Queen_Spade, 8. King_Club, 9. King_Diamond, 10. 2_Spade, 11. 2_Heart,
# [0, 49, 52]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. Queen_Club, 9. King_Spade, 10. King_Heart, 11. Ace_Heart,
# [0, 48]
# 48
# Tây chặt bài với: Ace_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Spade, 3. 6_Heart, 4. 8_Diamond, 5. 9_Club, 6. 9_Heart, 7. 10_Diamond, 8. Jack_Spade, 9. Jack_Club, 10. Queen_Diamond, 11. Ace_Spade,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1.
Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 7_Club, 1. 7_Diamond, 2. 7_Heart, 3. 8_Club, 4. Queen_Spade, 5. King_Club, 6. King_Diamond, 7. 2_Spade, 8. 2_Heart,
# [0, 18, 19, 20, 22, 37, 42, 43, 49, 52]
# 18
# Bắc chặt bài với: 7_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. Queen_Club, 9. King_Spade, 10. King_Heart,
# [0, 24, 25, 30, 38, 41, 44]
# 38
# Tây chặt bài với: Queen_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond, 7. Ace_Spade,
# [0, 39, 45]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond, 2. 5_Diamond, 3. Jack_Diamond, 4. Jack_Heart, 5. Ace_Club, 6. 2_Diamond,
# [0, 46, 51]
# 46
# Đông chặt bài với: Ace_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 7_Diamond, 1. 7_Heart, 2. 8_Club, 3. Queen_Spade, 4. King_Club, 5. King_Diamond, 6. 2_Spade, 7. 2_Heart,
# [0, 49, 52]
# 52
# Bắc chặt bài với: 2_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. King_Spade, 9. King_Heart,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond, 7. Ace_Spade,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond, 2. 5_Diamond, 3. Jack_Diamond, 4. Jack_Heart, 5. 2_Diamond,
# [0]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 7_Diamond, 1. 7_Heart, 2. 8_Club, 3. Queen_Spade, 4. King_Club, 5. King_Diamond, 6. 2_Spade,
# [0, 19, 20, 22, 37, 42, 43, 49, 67, 84]
# 67
# Bắc khởi đầu vòng mới với: 7_Diamond, 7_Heart, Type: Pair
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. King_Spade, 9. King_Heart,
# [0, 85]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond, 7. Ace_Spade,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond, 2. 5_Diamond, 3. Jack_Diamond, 4. Jack_Heart, 5. 2_Diamond,
# [0, 79]
# 79
# Đông chặt bài với: Jack_Diamond, Jack_Heart, Type: Pair
# ----------------------------------------------------------------------------------------------------
# 0. 8_Club, 1. Queen_Spade, 2. King_Club, 3. King_Diamond, 4. 2_Spade,
# [0, 84]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond, 2. 5_Diamond, 3. 2_Diamond,
# [0, 2, 3, 11, 51, 54]
# 11
# Đông khởi đầu vòng mới với: 5_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 8_Club, 1. Queen_Spade, 2. King_Club, 3. King_Diamond, 4. 2_Spade,
# [0, 22, 37, 42, 43, 49]
# 22
# Bắc chặt bài với: 8_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. King_Spade, 9. King_Heart,
# [0, 24, 25, 30, 41, 44]
# 44
# Tây chặt bài với: King_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond, 7. Ace_Spade,
# [0, 45]
# 45
# Nam chặt bài với: Ace_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond, 2. 2_Diamond,
# [0, 51]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. Queen_Spade, 1. King_Club, 2. King_Diamond, 3. 2_Spade,
# [0, 49]
# 49
# Bắc chặt bài với: 2_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. King_Spade,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond, 2. 2_Diamond,
# [0, 51]
# 51
# Đông chặt bài với: 2_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. Queen_Spade, 1. King_Club, 2. King_Diamond,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. King_Spade,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Diamond,
# [0, 2, 3, 54]
# 3
# Đông khởi đầu vòng mới với: 3_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. Queen_Spade, 1. King_Club, 2. King_Diamond,
# [0, 37, 42, 43]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 6_Diamond, 5. 8_Heart, 6. 9_Spade, 7. 10_Club, 8. King_Spade,
# [0, 5, 7, 12, 14, 15, 24, 25, 30, 41]
# 15
# Tây chặt bài với: 6_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 6_Heart, 3. 8_Diamond, 4. 9_Heart, 5. Jack_Club, 6. Queen_Diamond,
# [0, 16, 23, 28, 34, 39]
# 16
# Nam chặt bài với: 6_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club,
# [0]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 8_Heart, 5. 9_Spade, 6. 10_Club, 7. King_Spade,
# [0, 24, 25, 30, 41]
# 41
# Tây chặt bài với: King_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 8_Diamond, 3. 9_Heart, 4. Jack_Club, 5. Queen_Diamond,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Diamond, 2. 5_Heart, 3. 6_Club, 4. 8_Heart, 5. 9_Spade, 6. 10_Club,
# [0, 5, 7, 12, 14, 24, 25, 30, 57, 135, 151]
# 7
# Tây khởi đầu vòng mới với: 4_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Spade, 2. 8_Diamond, 3. 9_Heart, 4. Jack_Club, 5. Queen_Diamond,
# [0, 9, 23, 28, 34, 39]
# 9
# Nam chặt bài với: 5_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club,
# [0]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. Queen_Spade, 1. King_Club, 2. King_Diamond,
# [0, 37, 42, 43]
# 37
# Bắc chặt bài với: Queen_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 5_Heart, 2. 6_Club, 3. 8_Heart, 4. 9_Spade, 5. 10_Club,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 8_Diamond, 2. 9_Heart, 3. Jack_Club, 4. Queen_Diamond,
# [0, 39]
# 39
# Nam chặt bài với: Queen_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. King_Club, 1. King_Diamond,
# [0, 42, 43]
# 43
# Bắc chặt bài với: King_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 8_Diamond, 2. 9_Heart, 3. Jack_Club,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. King_Club,
# [0, 42]
# 42
# Bắc khởi đầu vòng mới với: King_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# Chúc mừng Bắc là người chiến thắng
#  Win, name:  Bắc  0    Lose, name:  Tây  6    Lose, name:  Nam  4    Lose, name:  Đông  1
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 5_Heart, 2. 6_Club, 3. 8_Heart, 4. 9_Spade, 5. 10_Club,
# [0]
# 0
# Tây khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 8_Diamond, 2. 9_Heart, 3. Jack_Club,
# [0]
# 0
# Nam khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club,
# [0]
# 0
# Đông khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
#
# [0]
# 0
# Bắc khởi đầu vòng mới nhưng không đánh gì
# 'Bắc'
