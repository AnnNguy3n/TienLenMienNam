# %%
import gym
import gym_TLMN
from colorama import Fore, Style


def main():
    env = gym.make('gym_TLMN-v0')
    env.reset()

    # print([i.name for i in env.players])

    for i in range(500):
        env.render()

        o,a,done,t = env.step(env.turn.action(env.dict_input))
        if done:
            break

    print(Fore.LIGHTGREEN_EX, 'Win, name:', Fore.LIGHTMAGENTA_EX, env.p_name_victory, Fore.LIGHTCYAN_EX, '0', end='   ')
    for p in env.players:
        if p.name != env.p_name_victory:
            print(Fore.LIGHTRED_EX, 'Lose, name:', Fore.LIGHTMAGENTA_EX, p.name, Fore.LIGHTCYAN_EX, p.amount_cards_remaining, end='   ')
    
    print(Style.RESET_ALL)

    for i in range(env.players.__len__()):
        env.render()

        o,a,done,t = env.step(env.turn.action(env.dict_input))

    return env.p_name_victory

# %%
main()
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 0. 7_Heart, 1. 3_Club, 2. Queen_Heart, 3. 2_Spade, 4. 10_Spade, 5. 9_Spade, 6. Queen_Spade, 7. King_Diamond, 8. 5_Heart, 9. 6_Club, 10. 9_Club, 11. Jack_Heart, 12. Ace_Club,
# Tây khởi đầu vòng mới với: 6_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 2_Diamond, 1. Ace_Spade, 2. King_Spade, 3. King_Heart, 4. 5_Diamond, 5. 7_Diamond, 6. 7_Club, 7. 10_Heart, 8. 6_Heart, 9. 6_Diamond, 10. 5_Spade, 11. 6_Spade, 12. 8_Club,
# Đông chặt bài với: King_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Club, 1. 3_Heart, 2. 4_Heart, 3. Queen_Club, 4. 4_Spade, 5. 9_Diamond, 6. Ace_Heart, 7. 4_Diamond, 8. 5_Club, 9. 9_Heart, 10. Ace_Diamond, 11. King_Club, 12. 8_Spade,
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 2_Heart, 1. 8_Diamond, 2. 10_Diamond, 3. 2_Club, 4. Jack_Spade, 5. 7_Spade, 6. 3_Diamond, 7. Jack_Diamond, 8. Queen_Diamond, 9. 3_Spade, 10. 8_Heart, 11. 10_Club, 12. Jack_Club,
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 7_Heart, 1. 3_Club, 2. Queen_Heart, 3. 2_Spade, 4. 10_Spade, 5. 9_Spade, 6. Queen_Spade, 7. King_Diamond, 8. 5_Heart, 9. 9_Club, 10. Jack_Heart, 11. Ace_Club,
# Tây chặt bài với: Ace_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 2_Diamond, 1. Ace_Spade, 2. King_Heart, 3. 5_Diamond, 4. 7_Diamond, 5. 7_Club, 6. 10_Heart, 7. 6_Heart, 8. 6_Diamond, 9. 5_Spade, 10. 6_Spade, 11. 8_Club,
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 7_Heart, 1. 3_Club, 2. Queen_Heart, 3. 2_Spade, 4. 10_Spade, 5. 9_Spade, 6. Queen_Spade, 7. King_Diamond, 8. 5_Heart, 9. 9_Club, 10. Jack_Heart,
# Tây khởi đầu vòng mới với: Queen_Spade, Queen_Heart, Type: Pair
# ----------------------------------------------------------------------------------------------------
# 0. 2_Diamond, 1. Ace_Spade, 2. King_Heart, 3. 5_Diamond, 4. 7_Diamond, 5. 7_Club, 6. 10_Heart, 7. 6_Heart, 8. 6_Diamond, 9. 5_Spade, 10. 6_Spade, 11. 8_Club,
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0.
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 10_Spade, 2. King_Diamond, 3. Jack_Heart,
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. Ace_Spade, 1. King_Heart, 2. 6_Heart, 3. 8_Club,
# Đông khởi đầu vòng mới với: 8_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Club, 2. 8_Spade,
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 8_Diamond, 1. 10_Diamond, 2. Jack_Spade, 3. 7_Spade, 4. 3_Diamond, 5. Jack_Diamond, 6. Queen_Diamond, 7. 3_Spade, 8. 8_Heart, 9. 10_Club, 10. Jack_Club,
# Bắc chặt bài với: Jack_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 10_Spade, 2. King_Diamond, 3. Jack_Heart,
# Tây chặt bài với: King_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. Ace_Spade, 1. King_Heart, 2. 6_Heart,
# Đông chặt bài với: King_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 8_Diamond, 1. 10_Diamond, 2. Jack_Spade, 3. 7_Spade, 4. 3_Diamond, 5. Queen_Diamond, 6. 3_Spade, 7. 8_Heart, 8. 10_Club, 9. Jack_Club,
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 10_Spade, 2. Jack_Heart,
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. Ace_Spade, 1. 6_Heart,
# Đông khởi đầu vòng mới với: 6_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Club, 2. 8_Spade,
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 8_Diamond, 1. 10_Diamond, 2. Jack_Spade, 3. 7_Spade, 4. 3_Diamond, 5. Queen_Diamond, 6. 3_Spade, 7. 8_Heart, 8. 10_Club, 9. Jack_Club,
# Bắc chặt bài với: Queen_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 10_Spade, 2. Jack_Heart,
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. Ace_Spade,
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 8_Diamond, 1. 10_Diamond, 2. Jack_Spade, 3. 7_Spade, 4. 3_Diamond, 5. 3_Spade, 6. 8_Heart, 7. 10_Club, 8. Jack_Club,
# Bắc khởi đầu vòng mới với: 3_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 10_Spade, 2. Jack_Heart,
# Tây chặt bài với: Jack_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. Ace_Spade,
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Club, 2. 8_Spade,
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 8_Diamond, 1. 10_Diamond, 2. Jack_Spade, 3. 7_Spade, 4. 3_Diamond, 5. 8_Heart, 6. 10_Club, 7. Jack_Club,
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 10_Spade,
# Tây khởi đầu vòng mới với: 3_Club, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. Ace_Spade,
# Đông chặt bài với: Ace_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# Chúc mừng Đông là người chiến thắng
#  Win, name:  Đông  0    Lose, name:  Nam  3    Lose, name:  Bắc  8    Lose, name:  Tây  1
# ----------------------------------------------------------------------------------------------------
# 0. 3_Heart, 1. 5_Club, 2. 8_Spade,
# Nam khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 8_Diamond, 1. 10_Diamond, 2. Jack_Spade, 3. 7_Spade, 4. 3_Diamond, 5. 8_Heart, 6. 10_Club, 7. Jack_Club,
# Bắc khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 10_Spade,
# Tây khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
#
# Đông khởi đầu vòng mới nhưng không đánh gì
# 'Đông'
