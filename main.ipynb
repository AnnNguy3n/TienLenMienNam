# %%
import gym
import gym_TLMN
from colorama import Fore, Style


def main():
    env = gym.make('gym_TLMN-v0')
    env.reset()

    # print([i.name for i in env.players])

    for i in range(500):
        env.render()

        o,a,done,t = env.step(env.turn.action(env.dict_input))
        if done:
            break

    print(Fore.LIGHTGREEN_EX, 'Win, name:', Fore.LIGHTMAGENTA_EX, env.p_name_victory, Fore.LIGHTCYAN_EX, '0', end='   ')
    for p in env.players:
        if p.name != env.p_name_victory:
            print(Fore.LIGHTRED_EX, 'Lose, name:', Fore.LIGHTMAGENTA_EX, p.name, Fore.LIGHTCYAN_EX, p.amount_cards_remaining, end='   ')
    
    print(Style.RESET_ALL)

    for i in range(env.players.__len__()):
        env.render()

        o,a,done,t = env.step(env.turn.action(env.dict_input))

    return env.p_name_victory

# %%
main()
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Heart, 2. 5_Club, 3. 6_Spade, 4. 6_Diamond, 5. 7_Club, 6. Jack_Spade, 7. Jack_Heart, 8. Queen_Diamond, 9. King_Heart, 10. Ace_Club, 11. Ace_Diamond, 12. 2_Diamond,
# [0, 2, 4, 10, 13, 15, 18, 33, 36, 39, 44, 46, 47, 51, 55, 63, 79, 87, 139, 165, 167, 168, 203, 204]
# 51
# Đông khởi đầu vòng mới với: 2_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 7_Heart, 2. 8_Diamond, 3. 9_Spade, 4. 9_Club, 5. 10_Spade, 6. 10_Diamond, 7. 10_Heart, 8. Jack_Club, 9. Queen_Spade, 10. King_Spade, 11. 2_Club, 12. 2_Heart,
# [0, 52]
# 52
# Nam chặt bài với: 2_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Club, 5. 8_Heart, 6. 9_Diamond, 7. 9_Heart, 8. 10_Club, 9. Queen_Heart, 10. King_Diamond, 11. Ace_Spade, 12. Ace_Heart,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Club, 2. 4_Diamond, 3. 5_Spade, 4. 5_Diamond, 5. 5_Heart, 6. 6_Club, 7. 6_Heart, 8. 7_Spade, 9. Jack_Diamond, 10. Queen_Club, 11. King_Club, 12. 2_Spade,
# [0, 351]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Heart, 2. 5_Club, 3. 6_Spade, 4. 6_Diamond, 5. 7_Club, 6. Jack_Spade, 7. Jack_Heart, 8. Queen_Diamond, 9. King_Heart, 10. Ace_Club, 11. Ace_Diamond,
# [0]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 7_Heart, 2. 8_Diamond, 3. 9_Spade, 4. 9_Club, 5. 10_Spade, 6. 10_Diamond, 7. 10_Heart, 8. Jack_Club, 9. Queen_Spade, 10. King_Spade, 11. 2_Club,
# [0, 1, 20, 23, 25, 26, 29, 31, 32, 34, 37, 41, 50, 71, 75, 76, 107, 146, 147, 150, 152, 153, 155, 158, 162, 186, 188, 189, 191, 194, 198, 223, 226, 230, 254, 258, 282]
# 155
# Nam khởi đầu vòng mới với: 9_Spade, 10_Spade, Jack_Club, Type: 3_straight
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Club, 5. 8_Heart, 6. 9_Diamond, 7. 9_Heart, 8. 10_Club, 9. Queen_Heart, 10. King_Diamond, 11. Ace_Spade, 12. Ace_Heart,
# [0, 166, 169]
# 169
# Tây chặt bài với: Queen_Heart, King_Diamond, Ace_Heart, Type: 3_straight
# ----------------------------------------------------------------------------------------------------
# 0. 4_Spade, 1. 4_Club, 2. 4_Diamond, 3. 5_Spade, 4. 5_Diamond, 5. 5_Heart, 6. 6_Club, 7. 6_Heart, 8. 7_Spade, 9. Jack_Diamond, 10. Queen_Club, 11. King_Club, 12. 2_Spade,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_
Type: 3_straight
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 7_Heart, 2. 8_Diamond, 3. 9_Club, 4. 10_Diamond, 5. 10_Heart, 6. Queen_Spade, 7. King_Spade,
# [0, 147, 152, 153]
# 152
# Nam chặt bài với: 8_Diamond, 9_Club, 10_Diamond, Type: 3_straight
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Heart, 5. 9_Diamond, 6. 9_Heart, 7. 10_Club, 8. Ace_Spade,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 4_Diamond, 1. 5_Heart, 2. 7_Spade,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Heart, 2. 6_Diamond, 3. Jack_Heart, 4. Ace_Club, 5. Ace_Diamond,
# [0]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 7_Heart, 2. 10_Heart, 3. Queen_Spade, 4. King_Spade,
# [0, 1, 20, 32, 37, 41]
# 41
# Nam khởi đầu vòng mới với: King_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Heart, 5. 9_Diamond, 6. 9_Heart, 7. 10_Club, 8. Ace_Spade,
# [0, 45]
# 45
# Tây chặt bài với: Ace_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Diamond, 1. 5_Heart, 2. 7_Spade,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Heart, 2. 6_Diamond, 3. Jack_Heart, 4. Ace_Club, 5. Ace_Diamond,
# [0, 46, 47]
# 47
# Đông chặt bài với: Ace_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 7_Heart, 2. 10_Heart, 3. Queen_Spade,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Heart, 5. 9_Diamond, 6. 9_Heart, 7. 10_Club,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 3_Heart, 2. 6_Diamond, 3. Jack_Heart, 4. Ace_Club,
# [0, 2, 4, 15, 36, 46, 55]
# 4
# Đông khởi đầu vòng mới với: 3_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 7_Heart, 2. 10_Heart, 3. Queen_Spade,
# [0, 20, 32, 37]
# 20
# Nam chặt bài với: 7_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Heart, 5. 9_Diamond, 6. 9_Heart, 7. 10_Club,
# [0, 21, 24, 27, 28, 30]
# 27
# Tây chặt bài với: 9_Diamond, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Diamond, 1. 5_Heart, 2. 7_Spade,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 6_Diamond, 2. Jack_Heart, 3. Ace_Club,
# [0, 36, 46]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. 10_Heart, 2. Queen_Spade,
# [0, 32, 37]
# 32
# Nam chặt bài với: 10_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Heart, 5. 9_Heart, 6. 10_Club,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. Queen_Spade,
# [0, 1, 37]
# 0
# Nam khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 7_Diamond, 3. 8_Spade, 4. 8_Heart, 5. 9_Heart, 6. 10_Club,
# [0, 3, 8, 19, 21, 24, 28, 30, 70, 149, 151, 187]
# 149
# Tây khởi đầu vòng mới với: 7_Diamond, 8_Spade, 9_Heart, Type: 3_straight
# ----------------------------------------------------------------------------------------------------
# 0. 4_Diamond, 1. 5_Heart, 2. 7_Spade,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 6_Diamond, 2. Jack_Heart, 3. Ace_Club,
# [0]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. Queen_Spade,
# [0]
# 0
# Nam không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 8_Heart, 3. 10_Club,
# [0, 3, 8, 24, 30]
# 24
# Tây khởi đầu vòng mới với: 8_Heart, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 4_Diamond, 1. 5_Heart, 2. 7_Spade,
# [0]
# 0
# Bắc không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 6_Diamond, 2. Jack_Heart, 3. Ace_Club,
# [0, 36, 46]
# 0
# Đông không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade, 1. Queen_Spade,
# [0, 37]
# 37
# Nam chặt bài với: Queen_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 10_Club,
# [0]
# 0
# Tây không chặt gì nên bị loại khỏi vòng
# ----------------------------------------------------------------------------------------------------
# 0. 3_Spade,
# [0, 1]
# 1
# Nam khởi đầu vòng mới với: 3_Spade, Type: Single
# ----------------------------------------------------------------------------------------------------
# Chúc mừng Nam là người chiến thắng
#  Win, name:  Nam  0    Lose, name:  Bắc  3    Lose, name:  Đông  4    Lose, name:  Tây  3
# ----------------------------------------------------------------------------------------------------
# 0. 3_Diamond, 1. 4_Heart, 2. 10_Club,
# [0]
# 0
# Tây khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 4_Diamond, 1. 5_Heart, 2. 7_Spade,
# [0]
# 0
# Bắc khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
# 0. 3_Club, 1. 6_Diamond, 2. Jack_Heart, 3. Ace_Club,
# [0]
# 0
# Đông khởi đầu vòng mới nhưng không đánh gì
# ----------------------------------------------------------------------------------------------------
#
# [0]
# 0
# Nam khởi đầu vòng mới nhưng không đánh gì
# 'Nam'
